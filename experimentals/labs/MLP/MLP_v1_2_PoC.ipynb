# %%
'''
------------------------------------------------------
MLP ENGINE V1.1: DISTINCIONES EN PASOS, PREDICCIONES
------------------------------------------------------

EN ESTA VERSIÓN SE ESTABLECEN DOS PUNTOS QUE SON POSIBLES E IMPORTANTES DE RESALTAR: 
- LA VARIABLE "PASOS" PUEDE SER MODIFICADA PARA ADAPTARSE A LA SEGMENTACÍON Y LA PREPARACIÓN DE LOS DATOS
- LA VARIABLE "TRAINING_PERCENTAGE" HACE REFERENCIA AL PORCENTAJE DE DATOS QUE SE USARÁN PARA ENTRENAMIENTO
- LA VARIABLE "NEURONS" HACE REFERENCIA AL NÚMERO DE NEURONAS QUE CONTEMPLA LA CAPA DE LA RED NEURONAL
- LA VARIABLE "PREDICCIONES" SE DISTINGUE DE "PASOS", YA QUE, EL No. DE PASOS ES INDISTINTO AL No. DE PREDICCIONES
    LA CUAL PUEDE ADAPTARSE DESDE 1, 2, 7, 31, 62, etc días.


'''
import pyodbc
import pandas as pd
from datetime import date, datetime, timedelta
import numpy as np
from dateutil.relativedelta import relativedelta
import matplotlib.pylab as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
# from keras.optimizers import SGD, RMSprop
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import IsolationForest

plt.rcParams['figure.figsize' ] = (16, 9)
plt.style.use('fast')

# %%
sql_server = """
DRIVER={ODBC Driver 17 for SQL Server};
server=US3RN4M3;
database=AdventureWorksDW2022;
Trusted_connection=yes;
"""

# %%
query = """
SELECT 
    CAST(f.OrderDate AS DATE) AS sales_date,
    CAST(SUM(f.OrderQuantity) AS INT) AS TotalVentas
FROM 
    FactInternetSales AS f
WHERE 
    f.OrderDate < '2013-12-01'
    AND f.ProductKey = 214  
GROUP BY 
    CAST(f.OrderDate AS DATE)
ORDER BY 
    CAST(f.OrderDate AS DATE) ASC;
"""

# %%
query2 = """
SELECT 
    CAST(f.OrderDate AS DATE) AS sales_date,
    CAST(SUM(f.OrderQuantity) AS INT) AS TotalVentas
FROM 
    FactInternetSales AS f
WHERE 
    f.ProductKey = 214  
GROUP BY 
    CAST(f.OrderDate AS DATE)
ORDER BY 
    CAST(f.OrderDate AS DATE) ASC;
"""

# %%
#CONSTANTES

PASOS = 31
TRAINING_PERCENTAGE = 0.7
N_PREDICTIONS = 31
EPOCHS = 100
NEURONS = 31 #Mismo que el de pasos


#NOTAS DE ESTA PARTE: el número de pasos no es correlativo al No. de predicciones
#ya que, las predicciones pudieran ser de 61 días y el No. de pasos siempre serán 31, ya que bajo
#ese proceso se hizo el entrenamiento

# %%
def get_sqlconnection(config_sqlServer):
    status = "inicializando...."
    try: 
        connection = pyodbc.connect(sql_server)
        status = "Conexion establecida satisfactoriamente"
    except Exception as e:
        status = "Error al establecer la conexión:"+e
    print(status)
    return connection

# %%
def set_index_datetime(data):
        if str(type(data) == "<class 'pandas.core.frame.DataFrame'>"):
            # data.sort_values('fecha', inplace=True)
            for column in data.columns: 
                try: 
                    pd.to_datetime(data[column])
                    data.set_index(column,inplace=True)
                    return data
                except Exception as e:  
                    pass
        else: 
            return 0

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def create_x_y_train(data):
    #(PC)
    values = data.values
    values = values.astype('float32')
    scaler = MinMaxScaler(feature_range=(-1, 1))
    values= values.reshape(-1, 1)
    scaled = scaler.fit_transform(values)
    reframed = series_to_supervised(scaled, PASOS, 1)
    #(PC)
    values = reframed.values
    
    #debemos obtener el total de datos de entrenamiento
    n_train_days = int(len(values) * TRAINING_PERCENTAGE)
    print("Total de datos: ",int(len(values)))

    #80% - entrenamiento 
    train = values[:n_train_days, :]
    print("entrenamiento: ",len(train))

    #20% - prueba
    test = values[n_train_days:, :]
    print("testing: ",len(test))
    x_train, y_train = train[:, :- 1], train[:, -1]
    x_val, y_val = test[:, :- 1], test[:, -1]
    x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
    x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
    print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
    return x_train, y_train, x_val, y_val, scaler, values

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(NEURONS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mse'])
    model.summary()
    return model

# %%
def entrenar_modelo(x_train, y_train, x_val, y_val, scaler, values, data, model):
    # early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_val, y_val), batch_size=PASOS)
    results=model.predict(x_val)

    #Validaciones #1
    plt.scatter(range(len(y_val)),y_val,c='g', label='Valores Reales')
    plt.scatter(range(len(results)),results,c='r', label='Valores Predecidos')
    plt.xlabel('Índice')
    plt.ylabel('Valores(escalados)')
    plt.title('Grafico de dispersión entre Valores reales vs Predecidos ')
    plt.legend()
    plt.figtext(0.01,0.01,"Realizado el: "+datetime.now().strftime('%H:%M:%S %d-%m-%Y'),fontsize=10,color="gray")
    plt.figtext(0.60,0.01,"Gestión de Innovación en Tecnología Informática S.C.P. | Grupo Consultores®", fontsize=10, color="gray")
    plt.show()

    #Validaciones #2 
    plt.plot(history.history['loss'],label='Pérdida de Entrenamiento')
    plt.plot(history.history['val_loss'],label='Pérdida de Validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.title('Grafico de Pérdidas de Entrenamiento y validación, según el # de Épocas')
    plt.legend()
    plt.figtext(0.01,0.01,"Realizado el: "+datetime.now().strftime('%H:%M:%S %d-%m-%Y'),fontsize=10,color="gray")
    plt.figtext(0.60,0.01,"Gestión de Innovación en Tecnología Informática S.C.P. | Grupo Consultores®", fontsize=10, color="gray")
    plt.show()

    #Validación #3
    plt.title('Grafico de MSE de acuerdo al # de Épocas')
    plt.plot(history.history['mse'],label='MSE de Entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('MSE')
    plt.legend()
    plt.figtext(0.01,0.01,"Realizado el: "+datetime.now().strftime('%H:%M:%S %d-%m-%Y'),fontsize=10,color="gray")
    plt.figtext(0.60,0.01,"Gestión de Innovación en Tecnología Informática S.C.P. | Grupo Consultores®", fontsize=10, color="gray")
    plt.show()

    #Preparamos la data a guardar en metadata
    datetim_e = datetime.now().strftime('%H:%M:%S %d-%m-%Y'), 
    # model_summary = model.summary()
    optimizer_model = model.optimizer.get_config()

    #metadata
    metadata = [
            {
                "TOTAL_DE_DATOS": str(data.size),
                "EPOCH": len(history.history['loss']),
                "FECHA_ENTRENAMIENTO": datetim_e,
                "FECHA_MODIFICACION": datetim_e
            },
            optimizer_model, 
            # model_summary
        ]
    print(metadata)


    #Obtener el 20% de la data
    ultimosDias = data[data.index[int(len(data)*TRAINING_PERCENTAGE)]:]
    values = ultimosDias.values
    values = values.astype('float32' )
    values = values.reshape(-1, 1)
    scaled = scaler.fit_transform(values)
    reframed = series_to_supervised(scaled, PASOS, 1)
    reframed.drop(reframed.columns[[PASOS]], axis=1, inplace=True)
    values = reframed.values
    print("Meses registrados: ",len(values))
    x_test = values[len(values)-1:, :]
    print("La cantidad de días son: ",x_test.size)
    
    #Tensor
    x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
    return model, x_test

# %%
def agregarNuevoValor(x_test,nuevoValor):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i] = x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1]=nuevoValor[0]
    return x_test

# %%
def eliminar_anomalias(dtaframe):
    dataFrame_anomalias = dtaframe.copy()
    modeloIsolation = IsolationForest(contamination=0.05)
    modeloIsolation.fit(dataFrame_anomalias)
    anomalias = modeloIsolation.predict(dataFrame_anomalias)
    dtaframe['anomalias' ] = anomalias
    dataFrameSinAnomalias = dtaframe[dtaframe['anomalias' ] != -1]
    dataFrameSinAnomalias = dataFrameSinAnomalias.drop('anomalias', axis=1)
    return dataFrameSinAnomalias

# %%
#core
with get_sqlconnection(sql_server) as cursor: 
    prepData = pd.read_sql_query(query,cursor)
    historyData = pd.read_sql_query(query2, cursor)

    prepData = set_index_datetime(prepData)
    historyData = set_index_datetime(historyData)

    #Switch the format on days or months
    try: 
        #Si se trata de meses
        first_day = datetime.strptime(prepData.index.min(),'%Y-%m') + relativedelta(months=1)
        last_day = datetime.strptime(prepData.index.max(), '%Y-%m' ) + relativedelta(months=1)
        future_days = [last_day + relativedelta(months=i) for i in range(N_PREDICTIONS)]
        for i in range(len(future_days)):
            future_days[i] = str(future_days[i])[:7]
        print("Month_format_detected")
    except Exception as e: 
        #si se trata de dias
        print("Days_format_detected")
        first_day = prepData.index.min() + timedelta(days=1)
        last_day = prepData.index.max() + timedelta(days=1)
        future_days = [last_day + timedelta(days=i) for i in range(N_PREDICTIONS)]
        for i in range(len(future_days)):
            future_days[i] = str(future_days[i])[:10]
    #END TRY

    future_data = pd.DataFrame(future_days, columns=['fecha'])
    print(prepData)
    model = crear_modeloFF()
    data =[]
    for column in prepData.columns:
        # print(column)
        data = prepData.filter([column])
        data.set_index(prepData.index, inplace=True)
        data = eliminar_anomalias(data)
        x_train, y_train, x_val, y_val, scaler, values = create_x_y_train(data)
        model, x_test = entrenar_modelo(x_train, y_train, x_val, y_val, scaler, values, data, model)
        #Entonces, convendría guardar x_test con los últimos datos
        copia_test = x_test
        results = []
        for i in range(N_PREDICTIONS):
            parcial = model.predict(x_test)
            results.append(parcial[0])
            x_test = agregarNuevoValor(x_test, parcial[0])
        print("la cantidad de datos son: ",(len(results)))
        adimen = [x for x in results]
        inverted = scaler.inverse_transform(adimen)
        future_data[column]= inverted.astype(int)
    future_data = set_index_datetime(future_data)
# Out:
# Conexion establecida satisfactoriamente
# Days_format_detected
#             TotalVentas
# sales_date
# 2012-12-28            2
# 2012-12-29            2
# 2012-12-30            2
# 2012-12-31            4
# 2013-01-01            2
# ...                 ...
# 2013-11-26            8
# 2013-11-27            8
# 2013-11-28            8
# 2013-11-29            5
# 2013-11-30            5
#
# [328 rows x 1 columns]
# C:\Users\JoCel\AppData\Local\Temp\ipykernel_23488\2191846126.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   prepData = pd.read_sql_query(query,cursor)
# C:\Users\JoCel\AppData\Local\Temp\ipykernel_23488\2191846126.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   historyData = pd.read_sql_query(query2, cursor)
# c:\GitHub\pronostico\pronostico\envprediccion\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1, 31)          │           992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 31)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            32 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,024 (4.00 KB)
#  Trainable params: 1,024 (4.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Total de datos:  284
# entrenamiento:  198
# testing:  86
# (198, 1, 31) (198,) (86, 1, 31) (86,)
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5660 - mse: 0.5193 - val_loss: 0.6463 - val_mse: 0.5979
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5748 - mse: 0.5201 - val_loss: 0.6148 - val_mse: 0.5372
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5655 - mse: 0.4856 - val_loss: 0.5913 - val_mse: 0.4965
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5210 - mse: 0.4397 - val_loss: 0.5703 - val_mse: 0.4618
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4955 - mse: 0.3961 - val_loss: 0.5541 - val_mse: 0.4308
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4834 - mse: 0.3743 - val_loss: 0.5443 - val_mse: 0.4091
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4652 - mse: 0.3571 - val_loss: 0.5328 - val_mse: 0.3892
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4764 - mse: 0.3722 - val_loss: 0.5211 - val_mse: 0.3718
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4411 - mse: 0.3235 - val_loss: 0.5130 - val_mse: 0.3606
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4280 - mse: 0.2963 - val_loss: 0.5037 - val_mse: 0.3489
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4131 - mse: 0.2826 - val_loss: 0.4914 - val_mse: 0.3339
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3993 - mse: 0.2657 - val_loss: 0.4854 - val_mse: 0.3266
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3823 - mse: 0.2437 - val_loss: 0.4780 - val_mse: 0.3190
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4036 - mse: 0.2671 - val_loss: 0.4733 - val_mse: 0.3139
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3931 - mse: 0.2580 - val_loss: 0.4718 - val_mse: 0.3132
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3827 - mse: 0.2495 - val_loss: 0.4674 - val_mse: 0.3091
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3820 - mse: 0.2429 - val_loss: 0.4626 - val_mse: 0.3040
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3434 - mse: 0.2049 - val_loss: 0.4617 - val_mse: 0.3016
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3727 - mse: 0.2324 - val_loss: 0.4627 - val_mse: 0.3012
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3706 - mse: 0.2288 - val_loss: 0.4638 - val_mse: 0.3021
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3613 - mse: 0.2268 - val_loss: 0.4637 - val_mse: 0.3005
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3899 - mse: 0.2526 - val_loss: 0.4620 - val_mse: 0.2983
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3639 - mse: 0.2208 - val_loss: 0.4603 - val_mse: 0.2967
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3249 - mse: 0.1982 - val_loss: 0.4638 - val_mse: 0.3008
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3417 - mse: 0.2137 - val_loss: 0.4632 - val_mse: 0.3002
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3377 - mse: 0.2100 - val_loss: 0.4610 - val_mse: 0.2993
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3592 - mse: 0.2303 - val_loss: 0.4610 - val_mse: 0.2991
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3590 - mse: 0.2340 - val_loss: 0.4624 - val_mse: 0.2986
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3646 - mse: 0.2388 - val_loss: 0.4638 - val_mse: 0.3003
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3502 - mse: 0.2176 - val_loss: 0.4649 - val_mse: 0.3028
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3462 - mse: 0.2048 - val_loss: 0.4651 - val_mse: 0.3036
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3493 - mse: 0.2187 - val_loss: 0.4674 - val_mse: 0.3059
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3301 - mse: 0.2001 - val_loss: 0.4657 - val_mse: 0.3040
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3238 - mse: 0.2008 - val_loss: 0.4601 - val_mse: 0.2980
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3467 - mse: 0.2091 - val_loss: 0.4560 - val_mse: 0.2938
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3651 - mse: 0.2372 - val_loss: 0.4560 - val_mse: 0.2946
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3552 - mse: 0.2172 - val_loss: 0.4621 - val_mse: 0.2993
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3460 - mse: 0.2101 - val_loss: 0.4659 - val_mse: 0.3026
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3360 - mse: 0.2100 - val_loss: 0.4642 - val_mse: 0.3013
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3116 - mse: 0.1760 - val_loss: 0.4599 - val_mse: 0.2985
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3557 - mse: 0.2251 - val_loss: 0.4632 - val_mse: 0.3015
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3366 - mse: 0.2076 - val_loss: 0.4652 - val_mse: 0.3024
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3420 - mse: 0.2101 - val_loss: 0.4625 - val_mse: 0.3009
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3310 - mse: 0.2118 - val_loss: 0.4624 - val_mse: 0.3016
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3255 - mse: 0.1903 - val_loss: 0.4649 - val_mse: 0.3026
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3435 - mse: 0.2079 - val_loss: 0.4624 - val_mse: 0.2991
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3339 - mse: 0.1958 - val_loss: 0.4591 - val_mse: 0.2951
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3448 - mse: 0.2245 - val_loss: 0.4638 - val_mse: 0.3000
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3318 - mse: 0.2104 - val_loss: 0.4676 - val_mse: 0.3049
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3459 - mse: 0.2048 - val_loss: 0.4634 - val_mse: 0.3018
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3448 - mse: 0.2120 - val_loss: 0.4671 - val_mse: 0.3040
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3250 - mse: 0.1995 - val_loss: 0.4718 - val_mse: 0.3081
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3395 - mse: 0.2145 - val_loss: 0.4726 - val_mse: 0.3094
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3316 - mse: 0.2076 - val_loss: 0.4674 - val_mse: 0.3042
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3168 - mse: 0.1920 - val_loss: 0.4648 - val_mse: 0.3032
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3482 - mse: 0.2143 - val_loss: 0.4641 - val_mse: 0.3022
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3455 - mse: 0.2201 - val_loss: 0.4652 - val_mse: 0.3021
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3351 - mse: 0.2163 - val_loss: 0.4658 - val_mse: 0.3024
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3208 - mse: 0.1975 - val_loss: 0.4661 - val_mse: 0.3028
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3243 - mse: 0.2014 - val_loss: 0.4633 - val_mse: 0.3019
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3318 - mse: 0.2017 - val_loss: 0.4630 - val_mse: 0.3009
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3635 - mse: 0.2318 - val_loss: 0.4631 - val_mse: 0.2999
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3243 - mse: 0.1965 - val_loss: 0.4607 - val_mse: 0.2972
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3278 - mse: 0.1971 - val_loss: 0.4627 - val_mse: 0.2982
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3207 - mse: 0.1915 - val_loss: 0.4642 - val_mse: 0.2994
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3271 - mse: 0.1980 - val_loss: 0.4587 - val_mse: 0.2940
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3005 - mse: 0.1760 - val_loss: 0.4592 - val_mse: 0.2968
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3303 - mse: 0.1965 - val_loss: 0.4592 - val_mse: 0.2966
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2968 - mse: 0.1754 - val_loss: 0.4619 - val_mse: 0.2996
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3219 - mse: 0.1905 - val_loss: 0.4599 - val_mse: 0.2981
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3210 - mse: 0.1929 - val_loss: 0.4643 - val_mse: 0.3007
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3262 - mse: 0.1932 - val_loss: 0.4633 - val_mse: 0.2998
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3360 - mse: 0.2050 - val_loss: 0.4663 - val_mse: 0.3022
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2854 - mse: 0.1670 - val_loss: 0.4642 - val_mse: 0.3021
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3065 - mse: 0.1824 - val_loss: 0.4623 - val_mse: 0.2997
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2968 - mse: 0.1720 - val_loss: 0.4618 - val_mse: 0.2986
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3408 - mse: 0.2224 - val_loss: 0.4663 - val_mse: 0.3033
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3288 - mse: 0.2039 - val_loss: 0.4671 - val_mse: 0.3046
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3011 - mse: 0.1754 - val_loss: 0.4629 - val_mse: 0.3010
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3305 - mse: 0.2045 - val_loss: 0.4589 - val_mse: 0.2976
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3165 - mse: 0.1943 - val_loss: 0.4646 - val_mse: 0.3013
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3463 - mse: 0.2165 - val_loss: 0.4613 - val_mse: 0.2977
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3174 - mse: 0.1914 - val_loss: 0.4568 - val_mse: 0.2946
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3148 - mse: 0.1905 - val_loss: 0.4611 - val_mse: 0.2984
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2988 - mse: 0.1786 - val_loss: 0.4633 - val_mse: 0.3010
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3299 - mse: 0.2020 - val_loss: 0.4608 - val_mse: 0.2999
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2888 - mse: 0.1693 - val_loss: 0.4640 - val_mse: 0.3033
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3084 - mse: 0.1814 - val_loss: 0.4609 - val_mse: 0.3005
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3175 - mse: 0.1936 - val_loss: 0.4671 - val_mse: 0.3057
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3536 - mse: 0.2376 - val_loss: 0.4591 - val_mse: 0.2982
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2965 - mse: 0.1700 - val_loss: 0.4578 - val_mse: 0.2969
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2874 - mse: 0.1648 - val_loss: 0.4626 - val_mse: 0.3031
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3110 - mse: 0.1878 - val_loss: 0.4621 - val_mse: 0.3025
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3228 - mse: 0.2053 - val_loss: 0.4611 - val_mse: 0.3004
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3013 - mse: 0.1742 - val_loss: 0.4582 - val_mse: 0.2969
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2908 - mse: 0.1734 - val_loss: 0.4579 - val_mse: 0.2973
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2979 - mse: 0.1766 - val_loss: 0.4600 - val_mse: 0.2993
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2837 - mse: 0.1657 - val_loss: 0.4585 - val_mse: 0.2974
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2925 - mse: 0.1664 - val_loss: 0.4576 - val_mse: 0.2973
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3148 - mse: 0.1945 - val_loss: 0.4616 - val_mse: 0.3006
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# [{'TOTAL_DE_DATOS': '315', 'EPOCH': 100, 'FECHA_ENTRENAMIENTO': ('11:07:01 23-05-2025',), 'FECHA_MODIFICACION': ('11:07:01 23-05-2025',)}, {'name': 'adam', 'learning_rate': 0.0010000000474974513, 'weight_decay': None, 'clipnorm': None, 'global_clipnorm': None, 'clipvalue': None, 'use_ema': False, 'ema_momentum': 0.99, 'ema_overwrite_frequency': None, 'loss_scale_factor': None, 'gradient_accumulation_steps': None, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}]
# Meses registrados:  64
# La cantidad de días son:  31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# la cantidad de datos son:  31

# %%
    future_data
# Out:
#             TotalVentas
# fecha
# 2013-12-01            7
# 2013-12-02            4
# 2013-12-03            6
# 2013-12-04            6
# 2013-12-05            6
# 2013-12-06            7
# 2013-12-07            8
# 2013-12-08            7
# 2013-12-09            5
# 2013-12-10            6
# 2013-12-11            7
# 2013-12-12            6
# 2013-12-13            8
# 2013-12-14            5
# 2013-12-15            6
# 2013-12-16            8
# 2013-12-17            7
# 2013-12-18            6
# 2013-12-19            8
# 2013-12-20            7
# 2013-12-21            6
# 2013-12-22            6
# 2013-12-23            7
# 2013-12-24            6
# 2013-12-25            7
# 2013-12-26            5
# 2013-12-27            5
# 2013-12-28            7
# 2013-12-29            6
# 2013-12-30            5
# 2013-12-31            8

# %%
prepData = historyData
prepData.index = pd.to_datetime(historyData.index)
future_data.index = pd.to_datetime(future_data.index)
start_date = '2013-11-30'
end_date = '2013-12-31'

# Filtra los datos por rango de fechas
filtered_data = prepData.loc[start_date:end_date]

# plt.plot(filtered_data.index, filtered_data['TotalVentas'],label='Historial {p0} - {p1}'.format(p0=str(first_day.year), p1= str(last_day.year-1)), marker='o')
plt.plot(filtered_data.index, filtered_data['TotalVentas'],label='Historial', marker='o')
# plt.plot(future_data.index, future_data['TotalVentas'],label='Predicción {p0}'.format(p0=str(last_day.year)), marker='x')
plt.plot(future_data.index, future_data['TotalVentas'],label='Predicción', marker='x')
xtics = data.index.union(future_data.index)[::10]

plt.xlabel('Fecha')
plt.ylabel('Cantidad de productos vendidos')
plt.title('Predicción de la demanda para el producto {p0}'.format(p0=str(214)))
plt.figtext(0.01,0.01,"Predicciones realizadas con el modelo: MLP",fontsize=10,color="gray")
plt.figtext(0.60,0.01,"Gestión de Innovación en Tecnología Informática S.C.P. | Grupo Consultores®", fontsize=10, color="gray")
plt.figtext(0.40,0.01, "SIPPBST V2.0")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()
